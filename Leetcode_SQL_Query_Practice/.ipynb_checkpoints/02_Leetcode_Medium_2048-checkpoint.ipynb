# %% [markdown]
# Problem link:
#     https://leetcode.ca/2021-11-01-2048-Next-Greater-Numerically-Balanced-Number/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
