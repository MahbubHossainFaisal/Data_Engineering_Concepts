# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### The edge case here:
#     The edge case is to first sort the table by sale_date and fruit columns. Because they may be not in row by row sequence in other cases.

# %% [markdown]
# My approach was:
#
#     1) first make a cte by sorting the table by sale_date and fruits column
#     2) Make cte2 from cte1 where fruits=apples
#     3) Make cte3 from cte1 where fruites = orange
#     4) Select sale_date and diff by joining the cte2 and cte3 tables.

# %% [markdown]
# Efficient approach:
#
#     1) first make a cte by sorting the table by sale_date and fruits column
#     2) add a forth column by making cte2, taking the orange num values ( means we are keeping apples and oranges num column side by side)
#     3) then make the select statement to bring the output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
