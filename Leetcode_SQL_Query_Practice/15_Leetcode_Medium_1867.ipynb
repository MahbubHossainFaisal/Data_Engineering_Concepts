# %% [markdown]
# Link: https://leetcode.ca/2021-07-17-1867-Orders-With-Maximum-Quantity-Above-Average/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
